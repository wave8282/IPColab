# %%
# !python --version
# Out:
# Python 3.12.11

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH02/p.jpg')
print(img.shape)
# Out:
# (256, 256, 3)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(RGB_img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
plt.imshow(RGB_img)

# %%
R_img, G_img, B_img = cv2.split(RGB_img)

# %%
print(R_img.shape)
print(G_img.shape)
print(B_img.shape)
# Out:
# (256, 256)
# (256, 256)
# (256, 256)

# %%
CImg = RGB_img

# %%
CImg[:, :, 0] = R_img
CImg[:, :, 1] = R_img
CImg[:, :, 2] = R_img

# %%
plt.imshow(CImg)

# %%
CImg[:, :, 0] = G_img
CImg[:, :, 1] = G_img
CImg[:, :, 2] = G_img

# %%
CImg[:, :, 0] = B_img
CImg[:, :, 1] = B_img
CImg[:, :, 2] = B_img

# %%
HSV_img = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2HSV)

# %%
print(HSV_img.shape)
# Out:
# (256, 256, 3)

# %%
H_img, S_img, V_img = cv2.split(HSV_img)

# %%
CImg[:, :, 0] = H_img
CImg[:, :, 1] = H_img
CImg[:, :, 2] = H_img
plt.imshow(CImg)
