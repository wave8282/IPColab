# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/ab.bmp')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg2, cmap='gray')
# Out:
# (256, 256, 3)

# %%
gPoint = np.zeros((gImg2.shape[0], gImg2.shape[1]), dtype=np.ubyte)

# %%
def saturation(val):
  if val > 255:
    return 255
  elif val < 0:
    return 0
  else:
    return val

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/a.bmp')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg2, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-703535497.py in <cell line: 0>()
#       1 img = cv2.imread('/content/drive/MyDrive/IP/CH03/a.bmp')
# ----> 2 print(img.shape)
#       3 gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#       4 plt.imshow(gImg2, cmap='gray')
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    pointVal = 255 - np.int32(gImg1[h, w])
    gPoint[h, w] = saturation(pointVal)

plt.imshow(gPoint, cmap='gray')

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
   pointaVal = np.int32(gImg1[h, w])
   gPoint[h, w] = saturation(pointVal)
plt.imshow(gPoint, cmap='gray')

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
   pointaVal = np.int32(gImg1[h, w]) | np.int32(gImg2[h, w])
   gPoint[h, w] = saturation(pointVal)
plt.imshow(gPoint, cmap='gray')

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/ab.bmp')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg2, cmap='gray')
# Out:
# (256, 256, 3)

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/L.jpg')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg1, cmap='gray')
# Out:
# (256, 256, 3)

# %%
planeNum = 8
planeValue = 1

for i in range(planeNum-1):
  planeValue *= 2

for i in range(gImg1.shape[0]):
  for j in range(gImg1.shape[1]):
    imValue = gImg1[i, j]
    imValue = (int)(imValue/planeValue);
    if(imValue % 2 == 0):
      imValue = 0
    else:
      imValue = 255
    gPoint[i, j] = imValue

  plt.imshow(gPoint, cmap='gray')

# %%
gWaterMarker = gImg2.copy()

# %%
for i in range(gImg1.shape[0]):
  for j in range(gImg1.shape[1]):
    imValue = gImg1[i, j]
    if(imValue >= 128):
      if (gWaterMarker[i, j] % 2 == 0):
        gWaterMarker[i, j] += 1
      else:
        if(gWaterMarker[i, j] % 2 == 1):
          gWaterMarker[i, j] -= 1


plt.imshow(gWaterMarker, cmap='gray')
