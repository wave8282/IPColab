# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread('/content/drive/MyDrive/IP/Images/abcdef.bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg, cmap='gray')
# cv2_imshow(gImg)
# Out:
# (256, 256, 3)

# %%
numLabels, labels = cv2.connectedComponents(img)
print(numLabels)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-3271822918.py in <cell line: 0>()
# ----> 1 numLabels, labels = cv2.connectedComponents(img)
#       2 print(numLabels)
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/connectedcomponents.cpp:5623: error: (-215:Assertion failed) L.channels() == 1 && I.channels() == 1 in function 'connectedComponents_sub1'

# %%
print(labels.shape)
print(labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1320972844.py in <cell line: 0>()
# ----> 1 print(labels.shape)
#       2 print(labels)
#
# NameError: name 'labels' is not defined

# %%
label_H = uint8
cv2_imshow(label)
# Out:
#   File "/tmp/ipython-input-3677302473.py", line 1
#     label_H =
#               ^
# SyntaxError: invalid syntax

# %%
bank = 255*np.ones_like(label_H)
labelImg = cv2.merge([label_H, bank, bank])
labelImg = cv2.cvtColor(labelImg, cv2.COLOR_HSV2RGB)
labelImg[label_H == 0] = 0
cv2_imshow(labelImg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2271950783.py in <cell line: 0>()
# ----> 1 bank = 255*np.ones_like(label_H)
#       2 labelImg = cv2.merge([label_H, bank, bank])
#       3 labelImg = cv2.cvtColor(labelImg, cv2.COLOR_HSV2RGB)
#       4 labelImg[label_H == 0] = 0
#       5 cv2_imshow(labelImg)
#
# NameError: name 'label_H' is not defined

# %%
img = cv2.imread('/content/drive/MyDrive/IP/Images/milkdrop.bmp')
print(img.shape)
gImg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# plt.imshow(gImg, cmap='gray'
cv2_imshow(gImg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
ret, thresh = cv2.threshold(gImg, 127, 255, 0)
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
contour, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
img = cv2.drawContours(img, contour, -1, (0, 0, 255), 1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
cv2.HuMoments = cv2.HuMoments(cv2.moments(thresh))
