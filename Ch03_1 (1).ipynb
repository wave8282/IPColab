# %% [markdown]
# ### 3. 영상의 산술 및 논리 연산

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/p.bmp')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(gImg1.shape)
plt.imshow(gImg1, cmap='gray')
print(gImg1.shape)
plt.imshow(gImg1, cmap='gray')
# Out:
# (256, 256, 3)
# (256, 256)
# (256, 256)

# %%
cv2_imshow(gImg1)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/s.bmp')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg2, cmap='gray')
# Out:
# (256, 256, 3)

# %%
gPlus = np.zeros(gImg1.shape[0], gImg1.shape[1], dtype=np.ubyte)
cv2.add(gImg1, gImg2, gPlus)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2525656280.py in <cell line: 0>()
# ----> 1 gPlus = np.zeros(gImg1.shape[0], gImg1.shape[1], dtype=np.ubyte)
#       2 cv2.add(gImg1, gImg2, gPlus)
#
# TypeError: argument for zeros() given by name ('dtype') and position (position 1)

# %%
gPlus = np.zeros(gImg1.shape, dtype=np.ubyte)
cv2.add(gImg1, gImg2, gPlus)
# Out:
# array([[138, 156, 177, ..., 211, 211, 212],
#        [150, 157, 152, ..., 248, 248, 252],
#        [131, 109, 131, ..., 255, 255, 253],
#        ...,
#        [255, 255, 255, ..., 255, 253, 251],
#        [224, 251, 255, ..., 255, 255, 255],
#        [144, 186, 239, ..., 252, 255, 255]], dtype=uint8)

# %%
gPlus = np.zeros((256,256), dtype=np.ubyte)
cv2.add(gImg1, gImg2, gPlus)
# Out:
# array([[138, 156, 177, ..., 211, 211, 212],
#        [150, 157, 152, ..., 248, 248, 252],
#        [131, 109, 131, ..., 255, 255, 253],
#        ...,
#        [255, 255, 255, ..., 255, 253, 251],
#        [224, 251, 255, ..., 255, 255, 255],
#        [144, 186, 239, ..., 252, 255, 255]], dtype=uint8)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    # gPlus[h][w] = gImg1[h][w] + gImg2[h][w]
    pValue = np.int32(gImg1[h][w]) + np.int32(gImg2[h][w])
    if pValue > 255:
      gPlus[h][w] = 255
    else:
      gPlus[h][w] = pValue

plt.imshow(gPlus, cmap='gray')

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    gPlus[h, w] = gImg1[h, w] * 0.5 +  gImg2[h, w] * 0.5

plt.imshow(gPlus, cmap='gray')

# %%
gPlus = np.zeros((256,256), dtype=np.ubyte)
cv2.add(gImg1, gImg2, gPlus)
# Out:
# array([[138, 156, 177, ..., 211, 211, 212],
#        [150, 157, 152, ..., 248, 248, 252],
#        [131, 109, 131, ..., 255, 255, 253],
#        ...,
#        [255, 255, 255, ..., 255, 253, 251],
#        [224, 251, 255, ..., 255, 255, 255],
#        [144, 186, 239, ..., 252, 255, 255]], dtype=uint8)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    gPlus[h, w] = gImg1[h, w] -  gImg2[h, w]
plt.imshow(gPlus, cmap='gray')
# Out:
# /tmp/ipython-input-2289316934.py:3: RuntimeWarning: overflow encountered in scalar subtract
#   gPlus[h, w] = gImg1[h, w] -  gImg2[h, w]

# %%
gMinus = np.zeros((gImg1.shape[0], gImg2.shape[1]), dtype=np.ubyte)
cv2.subtract(gImg1, gImg2, gMinus)
# Out:
# array([[ 6, 26, 49, ...,  0,  0,  0],
#        [22, 27, 26, ..., 16, 18, 22],
#        [ 7,  0,  1, ..., 35, 31, 31],
#        ...,
#        [79, 85, 89, ..., 59, 57, 53],
#        [48, 73, 82, ..., 61, 62, 61],
#        [ 0,  2, 55, ..., 54, 61, 65]], dtype=uint8)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    gMinus[h, w] = np.abs(np.int32(gImg1[h, w]) -  np.int32(gImg2[h, w]))
plt.imshow(gMinus, cmap='gray')

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/s.bmp')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg1, cmap='gray')
# Out:
# (256, 256, 3)

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/m.bmp')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg2, cmap='gray')
# Out:
# (256, 256, 3)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    gPlus[h, w] = gImg1[h, w] -  gImg2[h, w]
plt.imshow(gPlus, cmap='gray')
# Out:
# /tmp/ipython-input-2289316934.py:3: RuntimeWarning: overflow encountered in scalar subtract
#   gPlus[h, w] = gImg1[h, w] -  gImg2[h, w]

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    gPlus[h, w] = gImg1[h, w] * 0.5 +  gImg2[h, w] * 0.5

plt.imshow(gPlus, cmap='gray')

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    gMinus[h, w] = np.abs(np.int32(gImg1[h, w]) -  np.int32(gImg2[h, w]))
plt.imshow(gMinus, cmap='gray')

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/k.jpg')
print(img)
gImg2 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg2, cmap='gray')
# Out:
# [[[ 36  45  48]
#   [ 35  40  41]
#   [ 36  41  50]
#   ...
#   [136 130 135]
#   [137 135 127]
#   [133 136 127]]
#
#  [[ 43  45  56]
#   [ 34  44  51]
#   [ 39  40  54]
#   ...
#   [143 139 128]
#   [140 134 129]
#   [145 142 121]]
#
#  [[ 38  43  44]
#   [ 43  40  49]
#   [ 58  42  53]
#   ...
#   [131 137 126]
#   [129 132 123]
#   [128 133 118]]
#
#  ...
#
#  [[  1   3   3]
#   [  3   3   3]
#   [  5   3   3]
#   ...
#   [ 47  64  61]
#   [ 91  92  82]
#   [ 93 105  99]]
#
#  [[ 11   8  10]
#   [ 12   8  13]
#   [ 10  10  10]
#   ...
#   [ 38  69  60]
#   [ 63  88  84]
#   [ 93 104 101]]
#
#  [[ 18  16  22]
#   [ 19  15  20]
#   [ 14  14  20]
#   ...
#   [ 41  57  56]
#   [ 58  79  70]
#   [ 78  98  93]]]

# %%
img = cv2.imread('/content/drive/MyDrive/IP/CH03/s.bmp')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gImg1, cmap='gray')
# Out:
# (256, 256, 3)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    gMinus[h, w] = np.abs(np.int32(gImg1[h, w]) -  np.int32(gImg2[h, w]))
plt.imshow(gMinus, cmap='gray')

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
      mulVal = np.int32(gImg1[h, w]) * np.int32(gImg2[h, w])
      if mulVal > 255:
        gMul = 255
      else:
        gMul = mulVal

plt.imshow(gMul, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4148424209.py in <cell line: 0>()
#       7         gMul = mulVal
#       8
# ----> 9 plt.imshow(gMul, cmap='gray')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5943             self.set_aspect(aspect)
#    5944
# -> 5945         im.set_data(X)
#    5946         im.set_alpha(alpha)
#    5947         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in set_data(self, A)
#     673         if isinstance(A, PIL.Image.Image):
#     674             A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 675         self._A = self._normalize_image_array(A)
#     676         self._imcache = None
#     677         self.stale = True
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in _normalize_image_array(A)
#     641             A = A.squeeze(-1)  # If just (M, N, 1), assume scalar and apply colormap.
#     642         if not (A.ndim == 2 or A.ndim == 3 and A.shape[-1] in [3, 4]):
# --> 643             raise TypeError(f"Invalid shape {A.shape} for image data")
#     644         if A.ndim == 3:
#     645             # If the input data has values outside the valid range (after
#
# TypeError: Invalid shape () for image data
